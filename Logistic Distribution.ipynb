# %%
sigmoid <- function(x){
    1/(1+exp(-x))
}

logistic <- function(x, mu, slope){
    sigmoid((x-mu)/slope)
}

pdf_logistic <- function(x, mu, s){
    sigmoid((x+0.5-mu)/s) - sigmoid((x-0.5-mu)/s)
}

cdf_logistic <- function(quantile, mu, s){
    
}

# %%
x = seq(-10, 20, length = 100)

# %%
plot(x,sigmoid((x-5)/2))
# Out:
# plot without title

# %%
pdf_logistic <- function(x, mu, s){
    sigmoid((x+0.5-mu)/s) - sigmoid((x-0.5-mu)/s)
}

# %%
plot(x, pdf_logistic(x, 5,2))
lines(x, pdf_logistic(x,9, 3))
# Out:
# plot without title
